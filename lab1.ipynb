# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\basil\OneDrive\Escritorio\Ironhack\labs\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv")
df
df.columns = df.columns.str.upper()
df
new_order = ["CUSTOMER", "GENDER", "ST","EDUCATION" ,"INCOME", "CUSTOMER LIFETIME VALUE", "VEHICLE CLASS", "POLICY TYPE", "NUMBER OF OPEN COMPLAINTS", "MONTHLY PREMIUM AUTO", "TOTAL CLAIM AMOUNT"]
df = df[new_order]
df
# Out:
#      CUSTOMER GENDER          ST             EDUCATION   INCOME  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 4003      NaN    NaN         NaN                   NaN      NaN
# 4004      NaN    NaN         NaN                   NaN      NaN
# 4005      NaN    NaN         NaN                   NaN      NaN
# 4006      NaN    NaN         NaN                   NaN      NaN
# 4007      NaN    NaN         NaN                   NaN      NaN
#
#      CUSTOMER LIFETIME VALUE  VEHICLE CLASS     POLICY TYPE  \
# 0                        NaN  Four-Door Car   Personal Auto
# 1                 697953.59%  Four-Door Car   Personal Auto
# ...

# %%
df1 = pd.read_csv(r"C:\Users\basil\OneDrive\Escritorio\Ironhack\labs\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv")
df1
df1.columns = df1.columns.str.upper()
df1
# Out:
#     CUSTOMER          ST GENDER EDUCATION CUSTOMER LIFETIME VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS  TOTAL CLAIM AMOUNT  \
# ...

# %%
df2 = pd.read_csv(r"C:\Users\basil\OneDrive\Escritorio\Ironhack\labs\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv")
df2
df2.columns = df2.columns.str.upper()
df2
df2 = df2.rename(columns={'STATE':'ST',})
df2
# Out:
#      CUSTOMER          ST  CUSTOMER LIFETIME VALUE             EDUCATION  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# ...

# %%
df.shape
# Out:
# (4008, 11)

# %%
df1.shape
# Out:
# (996, 11)

# %%
df2.shape
# Out:
# (7070, 11)

# %%
data = pd.concat([df, df1, df2], axis=0)
data
# Out:
#      CUSTOMER GENDER          ST             EDUCATION   INCOME  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#      CUSTOMER LIFETIME VALUE  VEHICLE CLASS     POLICY TYPE  \
# 0                        NaN  Four-Door Car   Personal Auto
# 1                 697953.59%  Four-Door Car   Personal Auto
# ...

# %%
data['CUSTOMER LIFETIME VALUE'] = data['CUSTOMER LIFETIME VALUE'].astype(str)
data['CUSTOMER LIFETIME VALUE'] = data['CUSTOMER LIFETIME VALUE'].str.replace('%', '')
data['CUSTOMER LIFETIME VALUE'] = data['CUSTOMER LIFETIME VALUE'].astype(float)

# %%
data.dtypes
# Out:
# CUSTOMER                      object
# GENDER                        object
# ST                            object
# EDUCATION                     object
# INCOME                       float64
# CUSTOMER LIFETIME VALUE      float64
# VEHICLE CLASS                 object
# POLICY TYPE                   object
# NUMBER OF OPEN COMPLAINTS     object
# MONTHLY PREMIUM AUTO         float64
# TOTAL CLAIM AMOUNT           float64
# dtype: object

# %%
data = data.drop(columns=["EDUCATION","NUMBER OF OPEN COMPLAINTS"])
data
# Out:
#      CUSTOMER  GENDER          ST   INCOME  CUSTOMER LIFETIME VALUE  \
# 0     RB50392     NaN  Washington      0.0                      NaN
# 1     QZ44356       F     Arizona      0.0               697953.59%
# 2     AI49188       F      Nevada  48767.0              1288743.17%
# 3     WW63253       M  California      0.0               764586.18%
# 4     GA49547       M  Washington  36357.0               536307.65%
# ...       ...     ...         ...      ...                      ...
# 7065      NaN     NaN         NaN      NaN                      NaN
# 7066      NaN     NaN         NaN      NaN                      NaN
# 7067      NaN     NaN         NaN      NaN                      NaN
# 7068      NaN     NaN         NaN      NaN                      NaN
# 7069      NaN     NaN         NaN      NaN                      NaN
#
#       VEHICLE CLASS     POLICY TYPE MONTHLY PREMIUM AUTO TOTAL CLAIM AMOUNT  \
# ...

# %%
data['CUSTOMER LIFETIME VALUE'] = data['CUSTOMER LIFETIME VALUE'] * 100
data
# Out:
#      CUSTOMER GENDER          ST             EDUCATION   INCOME  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#       CUSTOMER LIFETIME VALUE  VEHICLE CLASS     POLICY TYPE  \
# 0                         NaN  Four-Door Car   Personal Auto
# 1                6.979536e+07  Four-Door Car   Personal Auto
# ...

# %%
data.drop_duplicates()
# Out:
#      CUSTOMER GENDER          ST             EDUCATION   INCOME  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#       CUSTOMER LIFETIME VALUE  VEHICLE CLASS     POLICY TYPE  \
# 0                         NaN  Four-Door Car   Personal Auto
# 1                6.979536e+07  Four-Door Car   Personal Auto
# ...
